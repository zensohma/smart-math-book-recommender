# %%
# 1. Load 
import pandas as pd
import joblib

books = pd.read_csv(
    "../data/processed/books_for_ml.csv"
)

books.shape
# Out:
# (14987, 6)

# %%
joblib.dump(
    model,
    "../ml/models/knn_model.pkl"
)

joblib.dump(
    vectorizer,
    "../ml/models/tfidf.pkl"
)

joblib.dump(
    books,
    "../ml/models/books.pkl"
)

joblib.dump(
    title_to_index,
    "../ml/models/title_to_index.pkl"
)

joblib.dump(
    tfidf_matrix,
    "../ml/models/tfidf_matrix.pkl"
)
# Out:
# ['../ml/models/tfidf_matrix.pkl']
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# setelah cleaning selesai
books = books.reset_index(drop=True)

# buat content
books["content"] = (
    books["title"].fillna("") + " " +
    books["author"].fillna("") + " " +
    books["description"].fillna("")
)

# HAPUS mapping lama
del title_to_index

# buat mapping baru
title_to_index = pd.Series(
    data=books.index,
    index=books["title"]
)

# %%
#3. content
books["content"] = (
    books["title"].fillna("") + " " +
    books["author"].fillna("") + " " +
    books["description"].fillna("")
)

# %%
#4. mapping
# 4. mapping
title_to_index = pd.Series(
    books.index,
    index=books["title"]
)

# %%
# 5. tfidf
vectorizer = TfidfVectorizer(
    stop_words="english",
    max_features=10000
)

tfidf_matrix = vectorizer.fit_transform(
    books["content"]
)

# %%
#6. Model
model = NearestNeighbors(
    metric="cosine",
    algorithm="brute"
)

model.fit(tfidf_matrix)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
title_to_index["1984"]
# Out:
# np.int64(4184)

# %%
books.iloc[title_to_index["1984"]]["title"]
# Out:
# '1984'

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(
    stop_words="english",
    max_features=10000
)

tfidf_matrix = tfidf.fit_transform(
    books["content"]
)

print(tfidf_matrix.shape)
# Out:
# (14987, 10000)

# %%
from sklearn.neighbors import NearestNeighbors

model = NearestNeighbors(
    metric="cosine",
    algorithm="brute",
    n_neighbors=6
)

model.fit(tfidf_matrix)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine', n_neighbors=6)

# %%
title_to_index = pd.Series(
    books.index,
    index=books["title"]
).drop_duplicates()

# %%
def recommend(book_title, top_n=5):

    if book_title not in title_to_index:
        return "Book not found"

    idx = title_to_index[book_title]

    distances, indices = model.kneighbors(
        tfidf_matrix[idx],
        n_neighbors=50
    )
    print("INDEX:", idx)
    print("BOOK:")
    recommendations = books.iloc[
        indices[0][1:]
    ][["title", "author"]]

    recommendations = recommendations.drop_duplicates(
        subset=["title"]
    )

    return recommendations.head(top_n)

# %%
books["title"].sample(20)
# Out:
# 13493                                      Hapgood: A Play
# 9058                                             Exzession
# 10189    Jojo's Bizarre Adventure, Tome 18: Death Thirteen
# 4736     Birdsongs of the Pacific Northwest [With CD (A...
# 7867                                      Noel Streatfeild
# 3737                                Nuestra Proxima Parada
# 696                                          The Alchemist
# 4752     Rats Alley: Trench Names of the Western Front ...
# 6418                                           Blood Sport
# 2475                     Nineveh and Its Remains, Volume 1
# 7461     Jesus: God or the Son of God?: A Comparison of...
# 5679     Winning the Future: A 21st Century Contract Wi...
# 1756     Mahatma Gandhi and His Myths: Civil Disobedien...
# 1932                                         Pipes Of Pan.
# 3947                                  The Heart of a Woman
# 10508    The Secret Science Project That Almost Ate the...
# ...

# %%
books["title"].sample(20)
# Out:
# 8366     Eat Right 4 Your Type: The Individualized Diet...
# 3912     For Esme—With Love and Squalor, and Other Stories
# 7384                                     Italian Folktales
# 13704                 Mass Media Research: An Introduction
# 2232                                        Flip-Flop Girl
# 6108                Anne of Green Gables / Anne of Avonlea
# 6599                     The Old Man Who Read Love Stories
# 1736               Family Reunion Planning Kit for Dummies
# 7864                                   . . .Has Far to Go.
# 624      Science and Sensibility: The Elegant Logic of ...
# 12979            Coppola and Eiko on Bram Stoker's Dracula
# 2060                    Innovation and the General Manager
# 13897                      Christopher Marlowe: Poet & Spy
# 5498                           Portraits of the Rainforest
# 6995                                    Anybody Out There?
# 9346                       Journey to the End of the Night
# ...

# %%
recommend('1984')
# Out:
# INDEX: 4184
# BOOK:
#                                                   title  \
# 4188                                   Animal Farm/1984
# 7272                                Homage to Catalonia
# 7278  The Orwell Reader: Fiction, Essays, and Reportage
# 9585                                   Thirteen O’Clock
# 7267                             A Collection of Essays
#
#                                         author
# 4188  George Orwell,Richard Brown,Ralph Cosham
# 7272             George Orwell,Lionel Trilling
# 7278           George Orwell,Richard H. Rovere
# 9585                           Thurston Clarke
# 7267                             George Orwell

# %%
books[books["title"] == "1984"][["title","author"]]
# Out:
#      title                                             author
# 4184  1984  George Orwell,Erich Fromm,Regina Silveira,Marc...

# %%
books[books["title"] == "1984"]["description"].iloc[0]
# Out:
# "The year 1984 has come and gone, but George Orwell's prophetic, nightmarish vision in 1949 of the world we were becoming is timelier than ever.,is still the great modern classic of \\negative utopia\\—a startlingly original and haunting novel that creates an imaginary world that is completely convincing, from the first sentence to the last four words. No one can deny th,The year 1984 has come and gone, but George Orwell's prophetic, nightmarish vision in 1949 of the world we were becoming is timelier than ever.,is still the great modern classic of \\negative utopia\\—a startlingly original and haunting novel that creates an imaginary world that is completely convincing, from the first sentence to the last four words. No one can deny the novel's hold on the imaginations of whole generations, or the power of its admonitions—a power that seems to grow, not lessen, with the passage of time."

# %%
books.index
# Out:
# RangeIndex(start=0, stop=14987, step=1)

# %%
books.head()
# Out:
#    bookId                                      title  \
# 0       1     Harry Potter and the Half-Blood Prince
# 1       2  Harry Potter and the Order of the Phoenix
# 2       3      Harry Potter and the Sorcerer's Stone
# 3       4    Harry Potter and the Chamber of Secrets
# 4       5   Harry Potter and the Prisoner of Azkaban
#
#                        author  \
# 0                J.K. Rowling
# 1  J.K. Rowling,Mary GrandPré
# 2  J.K. Rowling,Mary GrandPré
# 3                J.K. Rowling
# 4  J.K. Rowling,Mary GrandPré
#
#                                               genres  \
# 0  Art,Biography,Business,Children's,Christian,Cl...
# 1  Art,Biography,Business,Children's,Christian,Cl...
# 2  Art,Biography,Business,Children's,Christian,Cl...
# 3  Art,Biography,Business,Children's,Christian,Cl...
# 4  Art,Biography,Business,Children's,Christian,Cl...
#
#                                          description  \
# 0  The war against Voldemort is not going well; e...
# ...

# %%
books = books.drop_duplicates(
    subset=["title"]
)

# %%
books[
    books["title"].str.contains(
        "Homo",
        case=False,
        na=False
    )
][["title", "description"]]
# Out:
#                                                    title  \
# 1061    Lysis/Phaedrus/Symposium: Plato on Homosexuality
# 7548                                          Homo Faber
# 7549   Das Frauenbild In Den Romanen Stiller Und Homo...
# 7550                                          Homo faber
# 7551                             Homo faber: Ein Bericht
# 7552                            Homo faber: Ein Bericht.
# 7553   Der Leser Im Dilemma: Die Leserrolle in Max Fr...
# 8291               Eight Ate: A Feast of Homonym Riddles
# 12664  Spiritual Bloomsbury: Hinduism and Homosexuali...
# 12669  Sexual Moralities in France, 1780-1980: New Id...
# 13742                                          Ecce Homo
#
#                                              description
# 1061   \And when the other is beside him, he shares h...
# 7548   Walter Faber is an emotionally detached engine...
# 7549   Das Anliegen dieser Untersuchung besteht wenig...
# ...

# %%
books.to_csv(
    "../data/processed/books_for_ml.csv",
    index=False
)

# %%
books["content"] = (
    books["title"].fillna("") + " " +
    books["author"].fillna("") + " " +
    books["genres"].fillna("") + " " +
    books["description"].fillna("")
)

# %%
books["content"].iloc[0][:500]
# Out:
# "Harry Potter and the Half-Blood Prince J.K. Rowling Art,Biography,Business,Children's,Christian,Classics,Comics,Cookbooks,Ebooks,Fantasy,Fiction,Graphic Novels,Historical Fiction,History,Horror,Memoir,Music,Mystery,Nonfiction,Poetry,Psychology,Romance,Science,Science Fiction,Self Help,Sports,Thriller,Travel,Young Adult,Art,Biography,Business,Children's,Christian,Classics,Comics,Cookbooks,Ebooks,Fantasy,Fiction,Graphic Novels,Historical Fiction,History,Horror,Memoir,Music,Mystery,Nonfiction,Poetr"

# %%
books.columns.tolist()
# Out:
# ['bookId', 'title', 'author', 'genres', 'description', 'content']

# %%
print(books["content"].iloc[4768][:500])
# Out:
# Howl's Moving Castle, Vol. 4 Hayao Miyazaki,Diana Wynne Jones Art,Biography,Business,Children's,Christian,Classics,Comics,Cookbooks,Ebooks,Fantasy,Fiction,Graphic Novels,Historical Fiction,History,Horror,Memoir,Music,Mystery,Nonfiction,Poetry,Psychology,Romance,Science,Science Fiction,Self Help,Sports,Thriller,Travel,Young Adult,Art,Biography,Business,Children's,Christian,Classics,Comics,Cookbooks,Ebooks,Fantasy,Fiction,Graphic Novels,Historical Fiction,History,Horror,Memoir,Music,Mystery,Nonfic

# %%
print(tfidf_matrix.shape)
# Out:
# (14987, 10000)

# %%
print(books.shape)
# Out:
# (14987, 6)

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarities = cosine_similarity(
    tfidf_matrix[4768],
    tfidf_matrix
)

similarities.shape
# Out:
# (1, 14987)

# %%
print(books.iloc[4768]["title"])
# Out:
# Howl's Moving Castle, Vol. 4

# %%
print(books.loc[4768, "title"])
# Out:
# Howl's Moving Castle, Vol. 4

# %%
print(books.loc[4184, "content"][:200])
# Out:
# 1984 George Orwell,Erich Fromm,Regina Silveira,Marc... Art,Biography,Business,Children's,Christian,Classics,Comics,Cookbooks,Ebooks,Fantasy,Fiction,Graphic Novels,Historical Fiction,History,Hor

# %%
idx = title_to_index["1984"]

print(idx)
print(books.iloc[idx]["title"])
# Out:
# 4184
# 1984

# %%
title_to_index = {
    title: idx
    for idx, title in enumerate(books["title"])
}
